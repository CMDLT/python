# %% [markdown]
# ## 认识数据

# %% [markdown]
# - 利用Pandas统计中位数、均值和众数

# %%
import pandas as pd
df = pd.DataFrame([[1, 2],[7, -4],[3, 9],[4, -4],[1, 3]],
                  columns = {'one','two'})

# %%
print('中位数：\n',df.median())
# Out:
# 中位数：
#  one    3.0
# two    2.0
# dtype: float64

# %%
print("均值：\n",df.mean(axis = 1))
# Out:
# 均值：
#  0    1.5
# 1    1.5
# 2    6.0
# 3    0.0
# 4    2.0
# dtype: float64

# %%
print("众数：\n",df.mode())
# Out:
# 众数：
#     one  two
# 0    1   -4

# %% [markdown]
# - 统计数据的分位数等统计量

# %%
import pandas as pd
df = pd.DataFrame([[1, 2],[7, -4],[3, 9],[3, -4]],
                  index = ['a','b','c','d'],columns = {'one','two'})

# %%
display(df)
# Out:
#    one  two
# a    1    2
# b    7   -4
# c    3    9
# d    3   -4

# %%
df.describe()
# Out:
#             one       two
# count  4.000000  4.000000
# mean   3.500000  0.750000
# std    2.516611  6.184658
# min    1.000000 -4.000000
# 25%    2.500000 -4.000000
# 50%    3.000000 -1.000000
# 75%    4.000000  3.750000
# max    7.000000  9.000000

# %% [markdown]
# - 利用 Matplotlib 绘制箱线图

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
np.random.seed(2)   # 设置随机种子
# 并生成 0 - 1 的 5 × 4 维度数据并存入 4 列DataFrame中
df = pd.DataFrame(np.random.rand(5, 4),
                 columns = ['A','B','C','D'])

# %%
plt.boxplot(df)
plt.show()

# %% [markdown]
# - Python 绘制散点图示例

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility 固定随机状态以实现再现性
np.random.seed(19680801)


N = 50
# # 随机产生 50 个 0 - 2 的 x，y 坐标
x = np.random.rand(N) * 2
y = np.random.rand(N) * 2
colors = np.random.rand(N)
# area = (30 * np.random.rand(N)) ** 2  # 0 to 15 point radii
area = np.pi * (10 * np.random.rand(n)) ** 2

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
n = 50
# 随机产生 50 个 0 - 2 的 x，y 坐标
x = np.random.rand(n) * 2
y = np.random.rand(n) * 2
# 随机产生 50 个 0 - 1 的颜色值
colors = np.random.rand(n)
area = np.pi * (10 * np.random.rand(n)) **2
# 点的半径范围：0 - 10
plt.scatter(x, y, s = area, c = colors, alpha = 0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


# Fixing random state for reproducibility # 修复随机状态以实现再现性
np.random.seed(19680801)

# unit area ellipse # 单位面积椭圆
rx, ry = 3., 1.
area = rx * ry * np.pi
theta = np.arange(0, 2 * np.pi + 0.01, 0.1)
verts = np.column_stack([rx / area * np.cos(theta), ry / area * np.sin(theta)])

x, y, s, c = np.random.rand(4, 30)
s *= 10**2.

fig, ax = plt.subplots()
ax.scatter(x, y, s, c, marker=verts)

plt.show()

# %% [markdown]
# #### 4、中列数

# %%
# 利用Python求均值、中位数和众数
import pandas as pd
import numpy as np
ss=pd.Series(np.random.randint(8,size=18)) #生成0~7的18个整数。
print(ss)
print('均值：\n',ss.mean())
print('中位数：\n',ss.median())
print('众数：\n',ss.mode())
# Out:
# 0     6
# 1     6
# 2     3
# 3     5
# 4     1
# 5     4
# 6     4
# 7     6
# 8     6
# 9     4
# 10    1
# 11    4
# 12    7
# 13    2
# 14    5
# 15    6
# 16    4
# 17    5
# dtype: int32
# 均值：
#  4.388888888888889
# 中位数：
#  4.5
# 众数：
#  0    4
# 1    6
# dtype: int32

# %% [markdown]
# ### 4.3.2 数据散布的度量

# %% [markdown]
# #### 1. 极差、四分位数和四分位数极差

# %% [markdown]
# ####  2. 五数概括、箱线图与离群点

# %%
# 例4.5 利用Python实现例4.4的箱线图。程序如下：
import matplotlib.pyplot as plt
import pandas as pd
ss=pd.Series([91,69,83,75,78,81,96,92,88,86]) #原始数据
plt.boxplot(ss) #绘制箱线图
plt.show()

# %% [markdown]
# #### 4.4.7 余弦相似性

# %%
# 例4.12 Python求余弦相似性示例。
# 求余弦相似性需要用到np.linalg.norm 操作，来求向量的范式，等同于求向量的欧式距离。
import numpy as np
X1=np.array([-0.4,0.8,0.5,-0.2,0.3])
X2=np.array([-0.5,0.4,-0.2,0.7,-0.1])
X1_norm=np.linalg.norm(X1)
X2_norm=np.linalg.norm(X2)
cos=np.dot(X1,X2)/(X1_norm*X2_norm) #引用计算内积函数np.dot()
print('X1和X2余弦相似性：',cos)
# Out:
# X1和X2余弦相似性： 0.23612240736068565

# %% [markdown]
# ### 4.5 数据可视化

# %% [markdown]
# #### 4.5.2 几何投影可视化技术
# - 1. 二维数据的散点图

# %%
# 例4.14 Python绘制二维散点图。
import matplotlib.pyplot as plt
import numpy as np
n = 50
x = np.random.rand(n)*2 #随机产生50个0~2之间的x,y坐标
y = np.random.rand(n)*2
colors = np.random.rand(50) #随产生50个0~1之间的颜色值
area = np.pi * (10 * np.random.rand(n))**2 #点的半径范围:0~10
plt.scatter(x, y, s=area, c=colors, alpha=0.5,marker=(9,2,30))
plt.show()

# %%
# 我把上面的marker 去掉后
import matplotlib.pyplot as plt
import numpy as np
n = 50
x = np.random.rand(n)*2 #随机产生50个0~2之间的x,y坐标
y = np.random.rand(n)*2
colors = np.random.rand(50) #随产生50个0~1之间的颜色值
area = np.pi * (10 * np.random.rand(n))**2 #点的半径范围:0~10
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# - 2. 三维数据的散点图

# %%
# 例4.15 利用鸢尾花数据集前三个特征，绘制三维散点图。
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D #空间三维画图 
from sklearn.datasets import load_iris
iris=load_iris() #导入鸢尾花
df=pd.DataFrame(iris.data[:],columns=iris.feature_names[:])
x=df['sepal length (cm)'] #设置x、y、z轴
y=df['sepal width (cm)']
z=df['petal length (cm)']
fig=plt.figure() #绘图
# ax=Axes3D(fig)
ax = plt.figure().add_subplot(projection='3d')
ax.scatter(x,y,z)
ax.set_xlabel('sepal length(cm)',fontdict={'size':10,'color': 'black'})
ax.set_xlabel('sepal width(cm)',fontdict={'size':10,'color': 'black'})
ax.set_xlabel('petal length(cm)',fontdict={'size':10,'color': 'black'})
plt.show()

# %% [markdown]
# - 3. 散点图矩阵
#     - 散点图矩阵（Scatter Matrix）是散点图的一种扩充，提供每个维与其它维的可视化。Python通过函数scatter_matrix()绘制散点图矩阵。

# %%
# 例4.16 绘制散点图矩阵示例。
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
v1 = np.random.normal(0, 1, 100)  #生成数据
v2 = np.random.randint(0, 23, 100)
v3 = v1 * v2
df = pd.DataFrame([v1, v2, v3]).T  #3*100的数据块
pd.plotting.scatter_matrix(df, diagonal='kde', color='b')  #绘制散点图矩阵
plt.show()

# %% [markdown]
# - 3. 平行坐标图
#     - 随着维度的增加，散点图矩阵变得不太有效。平行坐标图（Parallel Coordinates Plot）是对于具有多个属性问题的一种可视化方法。在平行坐标图中，数据集的一行数据在平行坐标图中用一条折线表示，纵向是属性值，横向是属性类别（用索引表示）。
#     - 利用Python绘制平行坐标图的方法有两种，一种是利用pandas包绘制；另一种利用plotly包绘制。这里只介绍利用pandas包绘制平行坐标图的示例。

# %%
# 例4.17  Pandas绘制平行坐标图示例。
import pandas as pd
import matplotlib.pyplot as plt 
from pandas.plotting import parallel_coordinates
import seaborn as sea
data=sea.load_dataset('iris')
fig,axes=plt.subplots()
parallel_coordinates(data,'species',ax=axes)
plt.legend(loc='upper center',bbox_to_anchor=(0.5,-0.1),ncol=3, fancybox=True,shadow=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6936/1977310390.py in <module>
#       4 from pandas.plotting import parallel_coordinates
#       5 import seaborn as sea
# ----> 6 data=sea.load_dataset('iris')
#       7 fig,axes=plt.subplots()
#       8 parallel_coordinates(data,'species',ax=axes)
#
# D:\Anaconda3\lib\site-packages\seaborn\utils.py in load_dataset(name, cache, data_home, **kws)
#     592         cache_path = os.path.join(get_data_home(data_home), os.path.basename(url))
#     593         if not os.path.exists(cache_path):
# --> 594             if name not in get_dataset_names():
#     595                 raise ValueError(f"'{name}' is not one of the example datasets.")
#     596             urlretrieve(url, cache_path)
#
# D:\Anaconda3\lib\site-packages\seaborn\utils.py in get_dataset_names()
#     518     """
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

ax = plt.figure().add_subplot(projection='3d')

# Plot a sin curve using the x and y axes.
x = np.linspace(0, 1, 100)
y = np.sin(x * 2 * np.pi) / 2 + 0.5
ax.plot(x, y, zs=0, zdir='z', label='curve in (x, y)')

# Plot scatterplot data (20 2D points per colour) on the x and z axes.
colors = ('r', 'g', 'b', 'k')

# Fixing random state for reproducibility
np.random.seed(19680801)

x = np.random.sample(20 * len(colors))
y = np.random.sample(20 * len(colors))
c_list = []
for c in colors:
    c_list.extend([c] * 20)
# By using zdir='y', the y value of these points is fixed to the zs value 0
# and the (x, y) points are plotted on the x and z axes.
ax.scatter(x, y, zs=0, zdir='y', c=c_list, label='points in (x, z)')

# Make legend, set axes limits and labels
ax.legend()
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.set_zlim(0, 1)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Customize the view angle so it's easier to see that the scatter points lie
# on the plane y=0
ax.view_init(elev=20., azim=-35)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ax = plt.figure().add_subplot(projection='3d')

# setting up a parametric curve
t = np.arange(0, 2*np.pi+.1, 0.01)
x, y, z = np.sin(t), np.cos(3*t), np.sin(5*t)

estep = 15
i = np.arange(t.size)
zuplims = (i % estep == 0) & (i // estep % 3 == 0)
zlolims = (i % estep == 0) & (i // estep % 3 == 2)

ax.errorbar(x, y, z, 0.2, zuplims=zuplims, zlolims=zlolims, errorevery=estep)

ax.set_xlabel("X label")
ax.set_ylabel("Y label")
ax.set_zlabel("Z label")

plt.show()

# %%
import turtle
turtle.color('red')
turtle.circle(80)
turtle.done()
